# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Shinta Khumaira]
# - **Email:** [Banoffe1993@gmail.com]
# - **ID Dicoding:** [ maira_14]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana perbedaan pola jumlah penyewaan sepeda per jam antara hari kerja (working day) dan hari libur (non-working day) sepanjang periode 2011-2012?
# - **Pertanyaan 2:** Bagaimana pengaruh variasi kondisi cuaca (weathersit) terhadap rata-rata jumlah penyewaan sepeda harian oleh pengguna tipe Casual dan Registered pada tahun 2012?
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
day_df = pd.read_csv("day.csv")
hour_df = pd.read_csv("hour.csv")

day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
# Cek info data, missing values, dan duplikasi
print(day_df.info())
print("Missing values in day_df:", day_df.isna().sum().sum())
print("Duplicates in day_df:", day_df.duplicated().sum())

print(hour_df.info())
print("Missing values in hour_df:", hour_df.isna().sum().sum())
print("Duplicates in hour_df:", hour_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None
# Missing values in day_df: 0
# Duplicates in day_df: 0
# ...

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data kolom dteday dari object ke datetime.
# - Mengubah angka kategorikal (seperti weathersit) menjadi label string agar mudah dibaca di grafik.

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
# Mapping label agar hasil EDA mudah dipahami
season_map = {1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'}
weather_map = {1: 'Clear', 2: 'Misty/Cloudy', 3: 'Light Snow/Rain', 4: 'Heavy Rain'}

# %%
day_df['season_label'] = day_df['season'].map(season_map)
day_df['weather_label'] = day_df['weathersit'].map(weather_map)

# %%
# Kita menggunakan hour_df sebagai basis agar data per jam tidak hilang
all_df = hour_df.merge(day_df, on='dteday', how='left', suffixes=('_hour', '_day'))

# %%
# Menyimpan dataset yang sudah digabung ke dalam file baru
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
day_df.describe(include="all")
# Out:
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  NaN         NaN         NaN         NaN
# top            NaN                  NaN         NaN         NaN         NaN
# freq           NaN                  NaN         NaN         NaN         NaN
# mean    366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min       1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%     183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%     366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%     548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max     731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std     211.165812                  NaN    1.110807    0.500342    3.451913
#
# ...

# %%
# EDA UNIVARIATE (Analisis Variabel Mandiri)
# Melihat ringkasan statistik untuk memahami distribusi data numerik
print("--- Deskripsi Statistik Variabel Numerik ---")
print(day_df[['temp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']].describe())
# Out:
# --- Deskripsi Statistik Variabel Numerik ---
#              temp         hum   windspeed       casual   registered  \
# count  731.000000  731.000000  731.000000   731.000000   731.000000
# mean     0.495385    0.627894    0.190486   848.176471  3656.172367
# std      0.183051    0.142429    0.077498   686.622488  1560.256377
# min      0.059130    0.000000    0.022392     2.000000    20.000000
# 25%      0.337083    0.520000    0.134950   315.500000  2497.000000
# 50%      0.498333    0.626667    0.180975   713.000000  3662.000000
# 75%      0.655417    0.730209    0.233214  1096.000000  4776.500000
# max      0.861667    0.972500    0.507463  3410.000000  6946.000000
#
#                cnt
# count   731.000000
# mean   4504.348837
# std    1937.211452
# min      22.000000
# 25%    3152.000000
# 50%    4548.000000
# 75%    5956.000000
# max    8714.000000

# %%
# EDA MULTIVARIATE (Hubungan Antar Variabel)
# Melihat korelasi antara variabel lingkungan dan jumlah total penyewaan
print("\n--- Matriks Korelasi (Multivariate) ---")
correlation = day_df[['temp', 'atemp', 'hum', 'windspeed', 'cnt']].corr()
print(correlation)
# Out:
# --- Matriks Korelasi (Multivariate) ---
#                temp     atemp       hum  windspeed       cnt
# temp       1.000000  0.991702  0.126963  -0.157944  0.627494
# atemp      0.991702  1.000000  0.139988  -0.183643  0.631066
# hum        0.126963  0.139988  1.000000  -0.248489 -0.100659
# windspeed -0.157944 -0.183643 -0.248489   1.000000 -0.234545
# cnt        0.627494  0.631066 -0.100659  -0.234545  1.000000

# %%
# EDA KATEGORIKAL & NUMERIKAL (Agregasi Data)
# Eksplorasi berdasarkan Musim (Season)
print("\n--- Analisis Penggunaan Berdasarkan Musim ---")
season_agg = day_df.groupby(by="season_label").agg({
    "instant": "nunique",
    "cnt": ["max", "min", "mean", "std"]
}).reindex(['Spring', 'Summer', 'Fall', 'Winter'])
print(season_agg)
# Out:
# --- Analisis Penggunaan Berdasarkan Musim ---
#              instant   cnt
#              nunique   max   min         mean          std
# season_label
# Spring           181  7836   431  2604.132597  1399.942119
# Summer           184  8362   795  4992.331522  1695.977235
# Fall             188  8714  1115  5644.303191  1459.800381
# Winter           178  8555    22  4728.162921  1699.615261

# %%
# Eksplorasi berdasarkan Kondisi Cuaca (Weather)
print("\n--- Analisis Penggunaan Berdasarkan Cuaca ---")
weather_agg = day_df.groupby(by="weather_label").agg({
    "cnt": ["max", "min", "mean", "std"]
})
print(weather_agg)
# Out:
# --- Analisis Penggunaan Berdasarkan Cuaca ---
#                   cnt
#                   max  min         mean          std
# weather_label
# Clear            8714  431  4876.786177  1879.483989
# Light Snow/Rain  4639   22  1803.285714  1240.284449
# Misty/Cloudy     8362  605  4035.862348  1809.109918

# %%
# Eksplorasi berdasarkan Tipe Pengguna (Casual vs Registered) per Bulan
print("\n--- Rata-rata Pengguna Casual vs Registered per Bulan ---")
monthly_user_agg = day_df.groupby(by="mnth").agg({
    "casual": "mean",
    "registered": "mean",
    "cnt": "mean"
})
print(monthly_user_agg)
# Out:
# --- Rata-rata Pengguna Casual vs Registered per Bulan ---
#            casual   registered          cnt
# mnth
# 1      194.225806  1982.112903  2176.338710
# 2      262.508772  2392.789474  2655.298246
# 3      716.838710  2975.419355  3692.258065
# 4     1013.366667  3471.533333  4484.900000
# 5     1214.274194  4135.500000  5349.774194
# 6     1231.766667  4540.600000  5772.366667
# 7     1260.596774  4303.080645  5563.677419
# 8     1161.919355  4502.500000  5664.419355
# 9     1172.050000  4594.466667  5766.516667
# 10     963.870968  4235.354839  5199.225806
# 11     610.050000  3637.133333  4247.183333
# 12     349.887097  3053.919355  3403.806452

# %%
# Eksplorasi jam tersibuk (Hourly) pada data hour_df
print("\n--- Jam dengan Rata-rata Penyewaan Tertinggi ---")
hourly_peak = hour_df.groupby(by="hr").cnt.mean().sort_values(ascending=False)
print(hourly_peak.head(5))
# Out:
# --- Jam dengan Rata-rata Penyewaan Tertinggi ---
# hr
# 17    461.452055
# 18    425.510989
# 8     359.011004
# 16    311.983562
# 19    311.523352
# Name: cnt, dtype: float64

# %%
#Eksplorasi Data hour_df
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %% [markdown]
# **Insight:** (Opsional)
#
# -Biasanya ada sekitar 4.504 sepeda yang disewa tiap harinya. Tapi, angkanya sering naik-turun tergantung situasi.
#
# -Efek Suhu: jika cuaca cerah, penyewa semakin banyak! Ada korelasi kuat (0.627) yang membuktikan orang lebih senang gowes pada cuaca cerah.
#
# -Musim Gugur jadi juaranya dengan rata-rata 5.644 sewa, sedangkan Musim Semi jadi musim  yang paling sepi.
#
# -Cuaca Cerah vs Hujan: Pas lagi Cerah, penyewaan bisa tembus rata-rata 4.876. Begitu turun hujan atau salju, peminatnya langsung anjlok cuma sisa 1.803 saja.
#
# -Member vs Casual: Pengguna Registered (member) adalah pengguna paling loyal. Jumlah mereka jauh lebih banyak dan pertumbuhannya lebih stabil dibanding penyewa Casual.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:Bagaimana perbedaan pola jumlah penyewaan sepeda per jam antara hari kerja (working day) dan hari libur (non-working day) sepanjang periode 2011-2012?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Menyiapkan data agregasi rata-rata penyewaan per jam berdasarkan status hari kerja
hourly_rentals = hour_df.groupby(['workingday', 'hr'])['cnt'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=hourly_rentals, x='hr', y='cnt', hue='workingday', marker='o', palette='tab10')

# Menambahkan detail informasi pada grafik
plt.title('Pola Penyewaan Sepeda per Jam: Hari Kerja vs Hari Libur (2011-2012)', fontsize=14)
plt.xlabel('Jam (00:00 - 23:00)', fontsize=12)
plt.ylabel('Rata-rata Jumlah Sewa', fontsize=12)
plt.xticks(range(0, 24))
plt.legend(title='Tipe Hari', labels=['Hari Libur / Akhir Pekan', 'Hari Kerja'])
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana pengaruh variasi kondisi cuaca (weathersit) terhadap rata-rata jumlah penyewaan sepeda harian oleh pengguna tipe Casual dan Registered pada tahun 2012?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data untuk tahun 2012
df_2012 = day_df[day_df['yr'] == 1].copy()

# Mapping label cuaca agar informatif
weather_map = {1: 'Cerah/Berawan', 2: 'Mendung/Kabut', 3: 'Hujan/Salju Ringan'}
df_2012['weather_label'] = df_2012['weathersit'].map(weather_map)

# Agregasi rata-rata penyewa casual dan registered berdasarkan cuaca
weather_user_analysis = df_2012.groupby('weather_label')[['casual', 'registered']].mean().reset_index()

# Reshape data untuk visualisasi
weather_melted = weather_user_analysis.melt(id_vars='weather_label', value_vars=['casual', 'registered'],
                                            var_name='Tipe Pengguna', value_name='Rata-rata Penyewaan')

# Membuat Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(data=weather_melted, x='weather_label', y='Rata-rata Penyewaan', hue='Tipe Pengguna', palette='Set2')

plt.title('Pengaruh Cuaca terhadap Rata-rata Penyewaan Casual vs Registered (Tahun 2012)')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Jumlah Sewa per Hari')
plt.legend(title='Tipe Pengguna')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Penyewaan di hari kerja memiliki dua puncak utama (08:00 dan 17:00), menunjukkan penggunaan untuk transportasi. Di hari libur, puncak terjadi di tengah hari (12:00-15:00) yang menunjukkan penggunaan untuk rekreasi.
# - **Conclusion pertanyaan 2:** Pengguna registered lebih stabil di berbagai cuaca dibanding pengguna casual yang turun drastis saat cuaca mulai mendung atau hujan ringan. Cuaca cerah memberikan angka tertinggi untuk kedua tipe pengguna.
# - ...

# %% [markdown]
# **Rekomendasi Action Item:**
# - Operasional: Pastikan ketersediaan sepeda maksimal di stasiun area perkantoran pada jam 08:00 dan 17:00 di hari kerja.
# - Marketing: Buat kampanye "Weekend Fun" yang menyasar pengguna casual saat cuaca diprediksi cerah di akhir pekan untuk mendongkrak penjualan.
