# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Shinta Khumaira]
# - **Email:** [Banoffe1993@gmail.com]
# - **ID Dicoding:** [maira_14]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana komparasi tren volume pengguna casual dan pengguna registered pada setiap bulannya?
# - **Pertanyaan 2:** pada bulan apa terjadi kenaikan jumlah pengguna casual dan registered paling besar dibandingkan dengan periode bulan sebelumnya?
# - **Pertanyaan 3:** Analisis fluktuasi tahunan: Bagaimana perbandingan pola pertumbuhan antara pengguna casual dan registered dari bulan ke bulan?"
# - **Pertanyaan 4:** Bagaimana pola penyewaan sepeda sepanjang hari, khususnya saat membandingkan jam sibuk dengan jam tidak sibuk? Selain itu, faktor eksternal apa saja yang memengaruhi perbedaan volume penggunaan tersebut?"

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ditahap ini dataset day.csv dan hour.csv akan diubah dijadikan dalam bentuk dataframe menggunakan library pandas

# %% [markdown]
# #### Load df ...

# %% [markdown]
# dataset Day

# %%
day_df = pd.read_csv('data/day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# dataset Hour

# %%
hour_df = pd.read_csv('data/hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# DataFrame Day

# %%
# MENILAI DATA day_df

# Periksa Tipe Data
day_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    str
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), str(1)
# memory usage: 98.6 KB

# %%
# Periksa duplikasi
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
# Ringkasam Parameter Statistik
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
# MENILAI DATA hour_df

# Periksa Tipe Data
hour_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  str
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), str(1)
# memory usage: 2.4 MB

# %%
# Periksa duplikasi
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
# Ringkasam Parameter Statistik
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
#  * Kolom dteday jadi datetime biar enak buat analisis waktu.
#
# * Buang instant karena cuma angka urut (indeks), nggak guna buat analisis.
#
# * Data sudah bersih, nggak ada yang kosong (missing) atau double (duplicate).'
#
# Tren Sewa: Angka penyewaan naik-turun banget, baik per jam maupun harian.
#
# User: Pengguna langganan (registered) jauh lebih banyak dibanding yang cuma iseng (casual).
#
# Cuaca: Suhu, angin, dan kelembaban variasinya cukup beragam.
#
# Waktu: Data tersebar rata 24 jam (rata-rata di jam 11-12 siang).

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Ditahap ini, kedua dataframe akan diubah tipe data pada colum 'dteday' menjadi 'datetime'

# %%
# Hapus kolom instant

hour_df.drop(['instant'], axis = 1, inplace= True)
day_df.drop(['instant'], axis = 1, inplace= True)

hour_df.head()
# Out:
#        dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1   0        0        6           0           1
# 1  2011-01-01       1   0     1   1        0        6           0           1
# 2  2011-01-01       1   0     1   2        0        6           0           1
# 3  2011-01-01       1   0     1   3        0        6           0           1
# 4  2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Ubah tipe data object ke date
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

print(hour_df['dteday'].dtype)
print(day_df['dteday'].dtype)
# Out:
# datetime64[us]
# datetime64[us]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Menghitung korelasi antar variabel numerik
plt.figure(figsize=(12, 8))
correlation_matrix = day_df.corr(numeric_only=True)

# Membuat Heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap Korelasi Antar Atribut')
plt.show()

# %%
# --- TAHAP SELEKSI FITUR ---

# Berdasarkan temuan pada Heatmap Correlation:
# 1. Menghapus 'atemp' karena multikolinearitas yang sangat tinggi (0.99) dengan 'temp'.
# 2. Menghapus 'casual' dan 'registered' karena merupakan komponen pembentuk variabel target 'cnt'.
#    Hal ini dilakukan untuk menghindari redundansi dan data leakage.
# 3. Variabel cuaca (weathersit, hum, windspeed) dan suhu (temp) tetap dipertahankan.

drop_columns = ['atemp', 'casual', 'registered']

# Implementasi penghapusan kolom pada day_df dan hour_df
day_df_final = day_df.drop(columns=drop_columns)
hour_df_final = hour_df.drop(columns=drop_columns)

# Menampilkan informasi hasil seleksi
print("### Hasil Seleksi Fitur (Feature Selection) ###")
print(f"Fitur yang dihapus: {drop_columns}")
print(f"Sisa fitur pada day_df ({len(day_df_final.columns)} kolom): \n{day_df_final.columns.tolist()}")
print(f"\nSisa fitur pada hour_df ({len(hour_df_final.columns)} kolom): \n{hour_df_final.columns.tolist()}")

# Menampilkan 5 data teratas untuk verifikasi
print("\nVerifikasi Data Teratas (day_df_final):")
day_df_final.head()
# Out:
# ### Hasil Seleksi Fitur (Feature Selection) ###
# Fitur yang dihapus: ['atemp', 'casual', 'registered']
# Sisa fitur pada day_df (12 kolom):
# ['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'hum', 'windspeed', 'cnt']
#
# Sisa fitur pada hour_df (13 kolom):
# ['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'hum', 'windspeed', 'cnt']
#
# Verifikasi Data Teratas (day_df_final):
#       dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1        0        6           0           2
# 1 2011-01-02       1   0     1        0        0           0           2
# 2 2011-01-03       1   0     1        0        1           1           1
# 3 2011-01-04       1   0     1        0        2           1           1
# 4 2011-01-05       1   0     1        0        3           1           1
#
#        temp       hum  windspeed   cnt
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# Ditahap ini dataframe yang sudah dibersihkan akan dieksplorasi agar dapat mengenali data selanjutnya

# %%
# Penggunaan sepeda per musim (day_df)
pivot_season = pd.pivot_table(day_df, values='cnt', index='season', aggfunc='sum', observed=True)
pivot_season.head()
# Out:
#             cnt
# season
# 1        471348
# 2        918589
# 3       1061129
# 4        841613

# %%
# Penggunaan sepeda per hari kerja (day_df)
pivot_workingday = pd.pivot_table(day_df, values='cnt', index='workingday', aggfunc='mean')
pivot_workingday.head()
# Out:
#                     cnt
# workingday
# 0           4330.168831
# 1           4584.820000

# %%
# Penggunaan sepeda per bulan (day_df)
pivot_month = pd.pivot_table(day_df, values='cnt', index='mnth', aggfunc='mean', observed=True)
pivot_month.head(12)
# Out:
#               cnt
# mnth
# 1     2176.338710
# 2     2655.298246
# 3     3692.258065
# 4     4484.900000
# 5     5349.774194
# 6     5772.366667
# 7     5563.677419
# 8     5664.419355
# 9     5766.516667
# 10    5199.225806
# 11    4247.183333
# 12    3403.806452

# %%
# Penggunaan sepeda per jam (hour_df)
pivot_hour = pd.pivot_table(hour_df, values='cnt', index='hr', aggfunc='mean')
pivot_hour.head(24)
# Out:
#            cnt
# hr
# 0    53.898072
# 1    33.375691
# 2    22.869930
# 3    11.727403
# 4     6.352941
# 5    19.889819
# 6    76.044138
# 7   212.064649
# 8   359.011004
# 9   219.309491
# 10  173.668501
# 11  208.143054
# 12  253.315934
# 13  253.661180
# 14  240.949246
# 15  251.233196
# 16  311.983562
# 17  461.452055
# 18  425.510989
# 19  311.523352
# 20  226.030220
# 21  172.314560
# 22  131.335165
# 23   87.831044

# %%
# Distribusi Penggunaan Sepeda (Harian)
distribusi_harian = day_df['cnt'].describe()
distribusi_harian.head(10)
# Out:
# count     731.000000
# mean     4504.348837
# std      1937.211452
# min        22.000000
# 25%      3152.000000
# 50%      4548.000000
# 75%      5956.000000
# max      8714.000000
# Name: cnt, dtype: float64

# %%
# Pengaruh Kondisi Cuaca terhadap Penggunaan Sepeda
pengaruh_cuaca = pd.pivot_table(day_df, values='cnt', index='weathersit', aggfunc='mean', observed=True)
pengaruh_cuaca.head()
# Out:
#                     cnt
# weathersit
# 1           4876.786177
# 2           4035.862348
# 3           1803.285714

# %%
# Hubungan Suhu dan Penggunaan Sepeda
korelasi_suhu = day_df[['temp', 'cnt']].corr()
korelasi_suhu.head()
# Out:
#           temp       cnt
# temp  1.000000  0.627494
# cnt   0.627494  1.000000

# %%
# Pengaruh Hari dalam Seminggu terhadap Penggunaan Sepeda
pengaruh_hari = pd.pivot_table(day_df, values='cnt', index='weekday', aggfunc='mean', observed=True)
pengaruh_hari.head(7)
# Out:
#                  cnt
# weekday
# 0        4228.828571
# 1        4338.123810
# 2        4510.663462
# 3        4548.538462
# 4        4667.259615
# 5        4690.288462
# 6        4550.542857

# %%
# Perbandingan Pengguna Casual dan Registered per Bulan
perbandingan_pengguna = day_df.groupby('mnth', observed=True)[['casual', 'registered']].sum()
perbandingan_pengguna.head(12)
# Out:
#       casual  registered
# mnth
# 1      12042      122891
# 2      14963      136389
# 3      44444      184476
# 4      60802      208292
# 5      75285      256401
# 6      73906      272436
# 7      78157      266791
# 8      72039      279155
# 9      70323      275668
# 10     59760      262592
# 11     36603      218228
# 12     21693      189343

# %%
# Bandingkan pengguna kasual dan terdaftar
data = day_df.groupby('mnth')[['casual', 'registered']].sum()
data = data.rename(columns={'casual': 'Kasual', 'registered': 'Terdaftar'})

# Hitung rata-rata
data.loc['Rata-rata'] = data.mean()

# Tampilkan tabel
print(data)
# Out:
#                  Kasual      Terdaftar
# mnth
# 1          12042.000000  122891.000000
# 2          14963.000000  136389.000000
# 3          44444.000000  184476.000000
# 4          60802.000000  208292.000000
# 5          75285.000000  256401.000000
# 6          73906.000000  272436.000000
# 7          78157.000000  266791.000000
# 8          72039.000000  279155.000000
# 9          70323.000000  275668.000000
# 10         59760.000000  262592.000000
# 11         36603.000000  218228.000000
# 12         21693.000000  189343.000000
# Rata-rata  51668.083333  222721.833333

# %%
# Menghitung pertumbuhan pengguna per bulan
casual_growth = day_df.groupby('mnth')['casual'].sum().pct_change() * 100
registered_growth = day_df.groupby('mnth')['registered'].sum().pct_change() * 100

# Menggabungkan data ke dalam tabel
growth_table = pd.DataFrame({
    'Kasual (%)': casual_growth,
    'Terdaftar (%)': registered_growth
})

# Menampilkan tabel
print(growth_table)
# Out:
#       Kasual (%)  Terdaftar (%)
# mnth
# 1            NaN            NaN
# 2      24.256768      10.983717
# 3     197.025997      35.257242
# 4      36.805868      12.910080
# 5      23.819940      23.096902
# 6      -1.831706       6.253876
# 7       5.751901      -2.072046
# 8      -7.827834       4.634339
# 9      -2.382043      -1.249127
# 10    -15.020690      -4.743387
# 11    -38.750000     -16.894650
# 12    -40.734366     -13.236157

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:  Bagaimana komparasi tren volume pengguna casual dan pengguna registered pada setiap bulannya?

# %%
sns.set_style("white")
plt.figure(figsize=(12, 6))

colors = ["#92c9e9", "#c43aad"]  
data = day_df.groupby('mnth')[['casual', 'registered']].sum()
data = data.rename(columns={'casual': 'Kasual', 'registered': 'Terdaftar'})

kasual_avg = data['Kasual'].mean()
terdaftar_avg = data['Terdaftar'].mean()

data.plot(kind='bar', color=colors, edgecolor='black', linewidth=0.7)

plt.axhline(kasual_avg, color='#92c9e9', linestyle='--', linewidth=1.5, alpha=0.8)
plt.axhline(terdaftar_avg, color='#c43aad', linestyle='--', linewidth=1.5, alpha=0.8)

plt.title('Perbandingan Pengguna Kasual dan Terdaftar per Bulan', fontsize=14, fontweight='bold')
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah Pengguna', fontsize=12)

plt.xticks(rotation=0)
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Pengguna terdaftar jauh lebih mendominasi dan stabil dibanding pengguna kasual yang fluktuatif. Strategi terbaik ke depan adalah memperkuat basis pengguna terdaftar ini karena mereka terbukti menjadi penyumbang volume terbesar secara konsisten.

# %% [markdown]
# ### Pertanyaan 2: : pada bulan apa terjadi kenaikan jumlah pengguna casual dan registered paling besar dibandingkan dengan periode bulan sebelumnya?

# %%
sns.set_style("white")

casual_growth = day_df.groupby('mnth')['casual'].sum().pct_change() * 100
registered_growth = day_df.groupby('mnth')['registered'].sum().pct_change() * 100

max_casual_idx = casual_growth.idxmax()
max_registered_idx = registered_growth.idxmax()

plt.figure(figsize=(14, 7))
x_labels = np.arange(len(casual_growth.index))

light_blue = "#92c9e9"
light_pink = "#c43aad"

bars1 = plt.bar(
    x_labels - 0.2, casual_growth, width=0.4, label='Kasual', color=light_blue
)
bars2 = plt.bar(
    x_labels + 0.2, registered_growth, width=0.4, label='Terdaftar', color=light_pink
)

for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    if casual_growth.index[i] == max_casual_idx:
        bar1.set_color("tab:blue") 
        bar1.set_edgecolor('black')
    if registered_growth.index[i] == max_registered_idx:
        bar2.set_color("tab:pink") 
        bar2.set_edgecolor('black')

plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Pertumbuhan (%)', fontsize=12)
plt.title('Pertumbuhan Pengguna Kasual dan Terdaftar per Bulan Paling Signifikan', fontsize=14, fontweight='bold')

plt.xticks(x_labels, casual_growth.index)
plt.axhline(0, color='black', linewidth=1, linestyle='--')
plt.legend(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Kenaikan paling signifikan terjadi di bulan ke-3, di mana jumlah pengguna kasual dan terdaftar sama-sama "ramai" dibanding bulan sebelumnya. Sepertinya ada faktor penentu di bulan Maret yang sukses menarik minat semua segmen pengguna secara serentak.

# %% [markdown]
# ### pertanyaan 3: Analisis fluktuasi tahunan: Bagaimana perbandingan pola pertumbuhan antara pengguna casual dan registered dari bulan ke bulan?"

# %%
sns.set_style("white")

plt.figure(figsize=(16, 5))

casual_data = day_df.groupby('mnth')['casual'].sum()
registered_data = day_df.groupby('mnth')['registered'].sum()

casual_avg = casual_data.mean()
registered_avg = registered_data.mean()

x_labels = np.arange(len(casual_data.index))

plt.plot(x_labels, casual_data, marker='o', linestyle='-', linewidth=2, color='tab:blue', label="Kasual")
plt.plot(x_labels, registered_data, marker='o', linestyle='-', linewidth=2, color='tab:pink', label="Terdaftar")

plt.axhline(casual_avg, color='blue', linestyle='--', linewidth=1.5)
plt.axhline(registered_avg, color='pink', linestyle='--', linewidth=1.5)

plt.xticks(x_labels, casual_data.index)

plt.title("Tren Pengguna Kasual dan Terdaftar Sepanjang Tahun", fontsize=16, fontweight='bold')
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah Pengguna', fontsize=12)
plt.legend(fontsize=10, loc="upper left")

plt.grid(False)
plt.show()

# %% [markdown]
# pengguna kasual sangat bergantung pada musim, jadi grafiknya naik-turun tajam. sedangkan, pengguna terdaftar lebih loyal dan stabil pola pemakaiannya. Ini membuktikan kalau alasan mereka pakai sepeda memang beda; yang satu buat jalan-jalan (kasual), yang satu buat rutinitas (terdaftar).

# %% [markdown]
# # Analisis Lanjutan Clustering

# %% [markdown]
# Pertanyaan 4: Bagaimana pola penyewaan sepeda sepanjang hari, khususnya saat membandingkan jam sibuk dengan jam tidak sibuk? Selain itu, faktor eksternal apa saja yang memengaruhi perbedaan volume penggunaan tersebut?"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Memuat Data (Pastikan file hour.csv tersedia di direktori kerja)
hour_df = pd.read_csv('data/hour.csv')

# 2. Tahap Seleksi Fitur (Sesuai kesepakatan analisis sebelumnya)
# Menghapus atemp (multikolinearitas), casual & registered (data leakage)
drop_columns = ['atemp', 'casual', 'registered']
hour_df_final = hour_df.drop(columns=drop_columns, errors='ignore')

# 3. Analisis Pola Jam Sibuk
# Menghitung rata-rata penyewaan untuk setiap jam dalam sehari
hourly_pattern = hour_df_final.groupby('hr')['cnt'].mean().reset_index()

# 4. Visualisasi Pola Penyewaan Sepeda
plt.figure(figsize=(12, 6))
sns.lineplot(x='hr', y='cnt', data=hourly_pattern, marker='o', color='teal', linewidth=2.5)
plt.fill_between(hourly_pattern['hr'], hourly_pattern['cnt'], color='teal', alpha=0.1)

# Highlight Area Jam Sibuk untuk kejelasan visual
plt.axvspan(7, 9, color='orange', alpha=0.2, label='Jam Sibuk Pagi (07:00-09:00)')
plt.axvspan(16, 19, color='red', alpha=0.2, label='Jam Sibuk Sore (16:00-19:00)')

plt.title('Pola Rata-rata Penyewaan Sepeda per Jam', fontsize=14)
plt.xlabel('Jam (00:00 - 23:00)', fontsize=12)
plt.ylabel('Rata-rata Jumlah Sewa (cnt)', fontsize=12)
plt.xticks(range(0, 24))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# 5. Analisis Faktor Eksternal (Korelasi Fitur Terpilih)
print("Korelasi Faktor Eksternal terhadap Jumlah Penyewaan (cnt):")
correlation_external = hour_df_final[['temp', 'hum', 'windspeed', 'weathersit', 'cnt']].corr()['cnt'].sort_values(ascending=False)
print(correlation_external.drop('cnt'))
# Out:
# Korelasi Faktor Eksternal terhadap Jumlah Penyewaan (cnt):
# temp          0.404772
# windspeed     0.093234
# weathersit   -0.142426
# hum          -0.322911
# Name: cnt, dtype: float64

# %%
# Berdasarkan grafik, misal: jam sibuk: 7-9 pagi dan 16-18 sore
def group_hours(hour):
    if 7 <= hour <= 9 or 16 <= hour <= 18:
        return 'Jam Sibuk'
    else:
        return 'Jam Tidak Sibuk'

hour_df['kelompok_jam'] = hour_df['hr'].apply(group_hours)

# Analisis karakteristik kelompok jam
cluster_characteristics = hour_df.groupby('kelompok_jam').agg({
    'weathersit': 'mean',
    'temp': 'mean',
    'weekday': lambda x: np.bincount(x.astype(int)).argmax(),  # Modus hari dalam seminggu
    'cnt': 'mean'
}).reset_index()

cluster_characteristics.head()
# Out:
#       kelompok_jam  weathersit      temp  weekday         cnt
# 0        Jam Sibuk    1.444038  0.505338        0  331.652552
# 1  Jam Tidak Sibuk    1.418985  0.494183        6  141.713221

# %%
# Urutkan data berdasarkan jumlah penggunaan sepeda
cluster_characteristics = cluster_characteristics.sort_values(by="cnt", ascending=False)

colors = ["#1f77b4" if cnt == cluster_characteristics["cnt"].max() else "#b5ccf0" for cnt in cluster_characteristics["cnt"]]
fig, ax = plt.subplots(figsize=(10, 5))

ax.pie(
    cluster_characteristics["cnt"],
    labels=cluster_characteristics["kelompok_jam"],
    autopct="%1.1f%%",
    colors=colors,
    startangle=180,  
    wedgeprops={"linewidth": 0, "edgecolor": "white"}  
)

plt.title("Rata-rata Penggunaan Sepeda per Kelompok Jam", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# Grafik menunjukkan dominasi penggunaan di jam sibuk dibandingkan jam santai. Pola ini mengonfirmasi kalau aktivitas bersepeda sangat terikat dengan jadwal harian pengguna, seperti jam kantor atau sekolah yang punya volume jauh lebih tinggi.

# %% [markdown]
# Conclution
#
# pertanyaan 1:
# * Pengguna Terdaftar adalah penyumbang volume terbesar dan paling stabil sepanjang tahun, sedangkan pengguna Kasual cenderung lebih sedikit dan sangat fluktuatif.
#
# * Penggunaan mencapai titik tertinggi pada Bulan 8 (±300rb pengguna terdaftar), didorong oleh cuaca musim panas yang ideal untuk bersepeda.
#
# * Penurunan drastis terjadi di Bulan 1 karena faktor cuaca dingin/ekstrem yang menghambat aktivitas luar ruangan.
#
# * Bulan 3 menjadi titik balik dengan lonjakan pertumbuhan paling signifikan (hingga 2x lipat untuk kasual), menandai transisi ke musim semi.
#
# * *Penggunaan didominasi oleh jam sibuk (berangkat/pulang kantor), yang menunjukkan bahwa layanan ini berfungsi utama sebagai alat transportasi rutinitas harian.
#
# pertanyaan 2:
# * Terjadi lonjakan luar biasa pada pengguna Kasual yang mencapai hampir 200%. Pengguna Terdaftar juga tumbuh stabil di angka ±35%. Karena Faktor transisi musim (awal musim semi) yang memicu minat bersepeda secara mendadak.
#
# * Pertumbuhan minus hingga -40% terjadi di akhir tahun.  Alasan: Cuaca ekstrem/dingin yang membuat orang berhenti bersepeda.
#
# * Pengguna Kasual jauh lebih sensitif terhadap musim , sementara pengguna Terdaftar lebih konsisten dan tahan banting terhadap perubahan cuaca.
#
# Pertanyaan 3:
# * Pengguna Terdaftar: Mencapai puncak tertinggi pada Bulan 8 (Agustus) dengan angka mendekati 300.000 pengguna.
#
# * Pengguna Kasual: Mencapai puncak pada Bulan 7 (Juli) di kisaran 75.000 - 80.000 pengguna. Puncak ini terjadi selama musim panas di mana kondisi cuaca sangat mendukung untuk aktivitas luar ruangan secara intensif.
#
# * Kedua tipe pengguna menyentuh titik terendah pada Bulan 1 (Januari), dengan pengguna kasual berada di bawah 20.000 dan terdaftar di kisaran 125.000. Penurunan drastis ini dipicu oleh cuaca ekstrem atau musim dingin yang membuat orang enggan bersepeda demi keamanan dan kenyamanan.
#
# pertanyaan 4:
# * Persentase jam sibuk: Mendominasi sebesar 70,1% dari total penggunaan sepeda. Lonjakan besar ini terjadi karena sepeda menjadi transportasi utama untuk rutinitas harian, seperti berangkat kerja atau sekolah, yang biasanya menumpuk di pagi dan sore hari.
#
# * Persentase jam tidak sibuk: Hanya menyumbang sebesar 29,9%. Pada jam-jam ini (seperti tengah malam atau siang hari saat jam kerja), aktivitas mobilitas masyarakat menurun drastis karena mayoritas sudah berada di lokasi tujuan atau sedang beristirahat
#
# Saran:
# * Prioritas Pengguna Terdaftar: Perkuat program loyalitas untuk pengguna Terdaftar karena mereka adalah penyumbang volume terbesar (±300rb saat puncak) dan paling stabil terhadap perubahan cuaca.
#
# * Promo Musiman Kasual: Berikan promo khusus pada Mei-September untuk menarik pengguna Kasual yang sangat aktif dan sensitif terhadap cuaca cerah di pertengahan tahun.
#
# * Manajemen Jam Sibuk: Pastikan stok sepeda tersedia di area perkantoran/sekolah pada Jam Sibuk (pagi & sore), karena mencakup 70,1% dari total penggunaan harian.
